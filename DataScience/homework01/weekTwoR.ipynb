# %%
library(ggplot2)

# %%
devtools::install_github("WinVector/WVPlots")
# Out:
# Downloading GitHub repo WinVector/WVPlots@master
# from URL https://api.github.com/repos/WinVector/WVPlots/zipball/master
# Installing WVPlots
# Installing sigr
# Installing pwr
# '/opt/microsoft/ropen/3.4.1/lib64/R/bin/R' --no-site-file --no-environ  \
#   --no-save --no-restore --quiet CMD INSTALL  \
#   '/tmp/Rtmpl17zj0/devtools671a268f9c/pwr' --library='/home/nbuser/R'  \
#   --install-tests
#
# '/opt/microsoft/ropen/3.4.1/lib64/R/bin/R' --no-site-file --no-environ  \
#   --no-save --no-restore --quiet CMD INSTALL  \
#   '/tmp/Rtmpl17zj0/devtools6741206134/sigr' --library='/home/nbuser/R'  \
#   --install-tests
#
# Installing wrapr
# '/opt/microsoft/ropen/3.4.1/lib64/R/bin/R' --no-site-file --no-environ  \
#   --no-save --no-restore --quiet CMD INSTALL  \
#   '/tmp/Rtmpl17zj0/devtools671cb5d533/wrapr' --library='/home/nbuser/R'  \
#   --install-tests
#
# '/opt/microsoft/ropen/3.4.1/lib64/R/bin/R' --no-site-file --no-environ  \
#   --no-save --no-restore --quiet CMD INSTALL  \
#   '/tmp/Rtmpl17zj0/devtools675567a0ff/WinVector-WVPlots-b733d55'  \
#   --library='/home/nbuser/R' --install-tests

# %%
library(WVPlots)

# %%
df <- read.csv('mlbootcamp5_train.csv')

# %%
head(df)
# Out:
#   id age   gender height weight ap_hi ap_lo cholesterol gluc smoke alco active
# 1 0  18393 2      168    62     110    80   1           1    0     0    1
# 2 1  20228 1      156    85     140    90   3           1    0     0    1
# 3 2  18857 1      165    64     130    70   3           1    0     0    0
# 4 3  17623 2      169    82     150   100   1           1    0     0    1
# 5 4  17474 1      156    56     100    60   1           1    0     0    0
# 6 8  21914 1      151    67     120    80   2           2    0     0    0
#   cardio
# 1 0
# 2 1
# 3 1
# 4 1
# 5 0
# 6 0

# %% [markdown]
# ## 1. Визуализируем корреляционную матрицу

# %% [markdown]
# * Для того чтобы лучше понять признаки в датасете, можно посчитать матрицу коэффициентов корреляции между признаками.

# %% [markdown]
# ## Какие два признака больше всего коррелируют (по Пирсону) с признаком height ?

# %% [markdown]
# * Gluc, Cholesterol
# * Weight, Alco
# * Smoke, Alco
# * ___Weight, Gender___

# %%
ro <- round(cor(df), 4)

# %%
ro
# Out:
#             id      age     gender  height  weight  ap_hi   ap_lo   cholesterol
# id           1.0000  0.0035  0.0035 -0.0030 -0.0018  0.0034 -0.0025  0.0061
# age          0.0035  1.0000 -0.0228 -0.0815  0.0537  0.0208  0.0176  0.1544
# gender       0.0035 -0.0228  1.0000  0.4990  0.1554  0.0060  0.0153 -0.0358
# height      -0.0030 -0.0815  0.4990  1.0000  0.2910  0.0055  0.0062 -0.0502
# weight      -0.0018  0.0537  0.1554  0.2910  1.0000  0.0307  0.0437  0.1418
# ap_hi        0.0034  0.0208  0.0060  0.0055  0.0307  1.0000  0.0161  0.0238
# ap_lo       -0.0025  0.0176  0.0153  0.0062  0.0437  0.0161  1.0000  0.0240
# cholesterol  0.0061  0.1544 -0.0358 -0.0502  0.1418  0.0238  0.0240  1.0000
# gluc         0.0025  0.0987 -0.0205 -0.0186  0.1069  0.0118  0.0108  0.4516
# smoke       -0.0037 -0.0476  0.3381  0.1880  0.0678 -0.0009  0.0052  0.0104
# alco         0.0012 -0.0297  0.1710  0.0944  0.0671  0.0014  0.0106  0.0358
# active       0.0038 -0.0099  0.0059 -0.0066 -0.0169  0.0000  0.0048  0.0099
# cardio       0.0038  0.2382  0.0081 -0.0108  0.1817  0.0545  0.0657  0.2211
#             gluc    smoke   alco    active  cardio
# id           0.0025 -0.0037  0.0012  0.0038  0.0038
# age          0.0987 -0.0476 -0.0297 -0.0099  0.2382
# gender      -0.0205  0.3381  0.1710  0.0059  0.0081
# height      -0.0186  0.1880  0.0944 -0.0066 -0.0108
# weight       0.1069  0.0678  0.0671 -0.0169  0.1817
# ap_hi        0.0118 -0.0009  0.0014  0.0000  0.0545
# ap_lo        0.0108  0.0052  0.0106  0.0048  0.0657
# cholesterol  0.4516  0.0104  0.0358  0.0099  0.2211
# gluc         1.0000 -0.0048  0.0112 -0.0068  0.0893
# smoke       -0.0048  1.0000  0.3401  0.0259 -0.0155
# alco         0.0112  0.3401  1.0000  0.0255 -0.0073
# active      -0.0068  0.0259  0.0255  1.0000 -0.0357
# cardio       0.0893 -0.0155 -0.0073 -0.0357  1.0000

# %%
heatmap(ro)

# %% [markdown]
# ## 2. Распределение роста для мужчин и женщин

# %% [markdown]
# ### Постройте violinplot для роста и пола. Используйте:

# %% [markdown]
# * hue – для разбивки по полу
# * scale – для оценки количества каждого из полов

# %%
ggplot(df, aes(x='df$gender', y=df$weight)) + 
  geom_violin(aes(fill=factor(df$gender)))

# %% [markdown]
# * Постройте на одном графике два отдельных kdeplot роста, отдельно для мужчин и женщин. На нем разница будет более наглядной, но нельзя будет оценить количество мужчин/женщин.

# %%
ggplot(df, aes(df$height, fill = factor(df$gender))) + 
  geom_density(alpha = 0.4)

# %% [markdown]
# ## 3.1 Какие признаки теперь больше всего коррелируют (по Спирмену) друг с другом?
# * Height, Weight
# * Age, Weight
# * __Ap_hi, Ap_lo__
# * Cholesterol, Gluc
# * Cardio, Cholesterol
# * Smoke, Alco

# %%
sp <- round(cor(df), 5)

# %%
sp
# Out:
#             id       age      gender   height   weight   ap_hi    ap_lo
# id           1.00000  0.00346  0.00350 -0.00304 -0.00183  0.00336 -0.00253
# age          0.00346  1.00000 -0.02281 -0.08152  0.05368  0.02076  0.01765
# gender       0.00350 -0.02281  1.00000  0.49903  0.15541  0.00601  0.01525
# height      -0.00304 -0.08152  0.49903  1.00000  0.29097  0.00549  0.00615
# weight      -0.00183  0.05368  0.15541  0.29097  1.00000  0.03070  0.04371
# ap_hi        0.00336  0.02076  0.00601  0.00549  0.03070  1.00000  0.01609
# ap_lo       -0.00253  0.01765  0.01525  0.00615  0.04371  0.01609  1.00000
# cholesterol  0.00611  0.15442 -0.03582 -0.05023  0.14177  0.02378  0.02402
# gluc         0.00247  0.09870 -0.02049 -0.01859  0.10686  0.01184  0.01081
# smoke       -0.00370 -0.04763  0.33814  0.18799  0.06778 -0.00092  0.00519
# alco         0.00121 -0.02972  0.17097  0.09442  0.06711  0.00141  0.01060
# active       0.00376 -0.00993  0.00587 -0.00657 -0.01687 -0.00003  0.00478
# cardio       0.00380  0.23816  0.00811 -0.01082  0.18166  0.05448  0.06572
#             cholesterol gluc     smoke    alco     active   cardio
# id           0.00611     0.00247 -0.00370  0.00121  0.00376  0.00380
# age          0.15442     0.09870 -0.04763 -0.02972 -0.00993  0.23816
# gender      -0.03582    -0.02049  0.33814  0.17097  0.00587  0.00811
# height      -0.05023    -0.01859  0.18799  0.09442 -0.00657 -0.01082
# weight       0.14177     0.10686  0.06778  0.06711 -0.01687  0.18166
# ap_hi        0.02378     0.01184 -0.00092  0.00141 -0.00003  0.05448
# ap_lo        0.02402     0.01081  0.00519  0.01060  0.00478  0.06572
# cholesterol  1.00000     0.45158  0.01035  0.03576  0.00991  0.22115
# gluc         0.45158     1.00000 -0.00476  0.01125 -0.00677  0.08931
# smoke        0.01035    -0.00476  1.00000  0.34009  0.02586 -0.01549
# alco         0.03576     0.01125  0.34009  1.00000  0.02548 -0.00733
# active       0.00991    -0.00677  0.02586  0.02548  1.00000 -0.03565
# cardio       0.22115     0.08931 -0.01549 -0.00733 -0.03565  1.00000

# %% [markdown]
# ## 4. Совместное распределение признаков
# * Постройте совместный график распределения jointplot двух наиболее коррелирующих между собой признаков (по Спирмену).
#
# * Кажется, наш график получился неинформативным из-за выбросов в значениях. Постройте тот же график, но с логарифмической шкалой (чтобы не получать OverflowError необходимо отфильтровать значения меньше либо равные нулю).

# %%
#ScatterHist(df, "height", "weight", "title")

# %% [markdown]
# _График в этом же репозитории: jointplot.jpg_

# %% [markdown]
# ## 5. Возраст
# * Посчитаем, сколько полных лет было респондентам на момент их занесения в базу.

# %% [markdown]
# * 44
# * 49
# * __53__
# * 62

# %%
df$age_years <- round(df$age / 365)
df_not_cardio <- subset(df,df$cardio == 0)
df_cardio <- subset(df,df$cardio == 1)

# %%
ggplot(df,aes(df$age_years,fill=factor(df$cardio))) + 
  geom_histogram(binwidth = 1, position = "dodge")
